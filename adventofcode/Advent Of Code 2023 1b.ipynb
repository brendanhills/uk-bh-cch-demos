# %%
print("hi")
# Out:
# hi

# %% [markdown]
# https://adventofcode.com/2023/day/1#part2

# %%
sample_text="""two1nine
eightwothree
abcone2threexyz
xtwone3four
4nineeightseven2
zoneight234
7pqrstsixteen"""

print(f"{sample_text=}")
# Out:
# sample_text='two1nine\neightwothree\nabcone2threexyz\nxtwone3four\n4nineeightseven2\nzoneight234\n7pqrstsixteen'

# %%
lines=sample_text.splitlines()
print(f"{lines=}")

def swap_words_for_int(line):
  print(f"{line=}")
  line = line.replace('one','1')
  line = line.replace('two','2')
  line = line.replace('three','3')
  line = line.replace('four','4')
  line = line.replace('five','5')
  line = line.replace('six','6')
  line = line.replace('seven','7')
  line = line.replace('eight','8')
  line = line.replace('nine','9')
  line = line.replace('ten','10')
  return line

for line in lines:
  print(swap_words_for_int(line))
# Out:
# lines=['two1nine', 'eightwothree', 'abcone2threexyz', 'xtwone3four', '4nineeightseven2', 'zoneight234', '7pqrstsixteen']
# line='two1nine'
# 219
# line='eightwothree'
# eigh23
# line='abcone2threexyz'
# abc123xyz
# line='xtwone3four'
# xtw134
# line='4nineeightseven2'
# 49872
# line='zoneight234'
# z1ight234
# line='7pqrstsixteen'
# 7pqrst6teen

# %%
def find_int_words(line):
    word_indexes = {"1", line.find("one")}
