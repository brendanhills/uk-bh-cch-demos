# %% [markdown]
# https://adventofcode.com/

# %% [markdown]
# # Day 1

# %% [markdown]
# Day 1: https://adventofcode.com/2023/day/1

# %% [markdown]
# https://adventofcode.com/2023/day/1/input

# %%
import urllib

# %%
test_string = """1abc2
pqr3stu8vwx
a1b2c3d4e5f
treb7uchet"""

print( test_string)

def calibration_value(input_string: str) -> int:
  total = 0
  lines = input_string.splitlines()
  for line in lines:
    print(line)
    digits = [int(c) for c in line if c.isdigit() ]
    sum_row=digits[0]*10+digits[-1]
    total=total+sum_row
    print(f" {digits=} First={digits[0]}, Last={digits[-1]} Sum={sum_row} {total=}")
  return total


print(f"Calibration: {calibration_value(test_string)}")

# %%
puzzle_input = """ fivethreeonezblqnsfk1
two74119onebtqgnine
jrjh5vsrxbhsfour3
tn5eightfncnzcdtthree8
kpmrk5flx
fkxxqxdfsixgthreepvzjxrkcfk6twofour
dqbx6six5twoone
glmsckj2bvmts1spctnjrtqhmbxzq
7sixthreerzmpbffcx
zhss9gfxfgmrmzthreefivevpkljfourtwoeight
6tfzvrbkfour
sevenfive66five851
drsgdrrgscqmsggrgq1fsqjhtkkrltt
3ftptvzhvrm5
twoeightninemfsztp2gbqkpgqvzt6threekcdcp
four156
959157fourfive
sixthreetwo87one7fourdbczdbjcc
lshzfive7
38ninethreethreesevensixeight
z39hpppnncfivenbkc
9ninefivevnbrrfrfjfivetwo
fzgnjsz2nine9
fnhksixfour1six81
vkkxbgcqzqflgsvgkkkpfp9five58stsix
eight26sixsghd
7zvrjkcrrgbsix
tgdf38fpcssixeightcjtfour
tcrqkxkptrtt5fdblcldfoursix
9qpmknkbtxsfourd
8948twosix9three8
vpbjslqkpbxkpfiveeight1mzjmhfzl
187jccxsbqtcjtwo1
sixfiveonefour637three
stjbeightsixdfnsppjrgfdggqzjx6cplvznllsgtwo
3lrznqgc85seven3
1eightfourfourmgxhdp51slrszbxmhthree
two3hj
zgnoneightseveneightseven5d2fivefourjp
ldjzhninetwokxlkbbzcngssdqphlrc51
qvhtfhmltt61lss
lfmnhxmhschzrtntwotwo7twovkl8two
vrpplrtqxvssgnvdf8
dzrnnphfl451
two7pgbsixlkmseven
rplqnj5oneseven
2fourfourchd7
threesixdpslzdft3hq
three4bqhlckrlgeight2lbdvcggfqd
ninefive6zqhgfhfdnk
2one9five2
1ftsjdfmnkvlx9seven
four1zsztlvnhcjtvmrlthree4kpztfzqjtdplfxpqlskh
6zfrhkckfvxsixtjgtnmcx
eightfourcppgkrmtn3chqxgscpd1
6threegxdrv8
mstpbscvjrc5twozjtdxhckrfsnzsdm
twolhntgone5
vtrktlkrqslcdnlslthree5
mfkrfournine4knmmmghnsixxrmzhcsix
2hfkbthree
nine96
threeqglpgvxgsdfgbctdm1
1threechctd2tnm
nfgrzrz494twogbrbcpvnine
two5fdnksffour
19threeninefive7xzmtzmkpjmnine
six37sixninejqt
kk28rqmlshb4
qmhlxonefbgcrclbf4sqtcpmtlzdzhg4b
leightwoplxmgrcjcxrfqncvjfdvpgckmqfqsfqjthreefour2djnsvctlt
oneseven2nxrcseven
fourthreefour5
53zsvpqnrjtwo5nine5nrdvmg
eight78twoone
bc6nf4zgnmkbnjts
xeightwopbgt7two
hqsnjjlbfivetwo84threepnine
br7oneeight2
ckxbsdjjttbxczfdpzmrxfh32eight
5212j912
1qhtwo3three9eight2nnjpbl
kdxx5five2ninebrvfzbbxptsccvdjgp
sixfpslbrfmqfvjs8seven
45qbcvqcjk6ninesix
98nine8
2eightonekcfvzfonethreenpxdpqtnvj
two87
jqnzhnzsdgg3eightfournbgsdxbfg31xrnv
4three3sxvnnzqvhcxj9
mpjmgpmninekffbkgprkb9tzzdznine8rtq
xhpfptdmpkeightdkqvpzscx7jndgsxxtqh
17vvktdvdgpthreeone1gqnb
fzpbhtmdvseven2one
sixzkkbjmnxnxm3gcvpsddqqgzktp63h
nineonexkqkfszg8qdzrlqszpltwo9cseven
7xfhtdfdldzplmrfivegpkgfseventwo
xvone5two7
fiveqdrgeightvrvtmtvvmnl2kbctwofive
three9rrxhddsdfive577
mnkltgsgs4fivefivekxzzhjdtnzzvmvxdh
blqtmklmkxcjtmxsrflffpzjcrninecd7rgdn8
jgpktmfourdxzll8threerlssqvslnb
4grvtbmlpqxgmzzksfgzvjggsqhffq1qcd
cninebtfvxfnmbtznfnzdh4zdmgtvbbnine
1seven4vkvqcktfourvjtd4zqh
8eight7lhmx89four
xrpxkdrf8fhl29fivexzsrdbmksixpvlk
8tvfplhxxxzr
twothree8nine2ninegfbrchxmmfive
9threeskhgsnsvvzpnnv2seven4
8sbzvncqszzdflznpqfddeight3
1eightzfivehlmhnqbnnr
sixfivefjfqftjvcdzkpbkhnvqrqqhpvmgnq75pfk
mtfvjbbpdeight1
txtfqxvbrnine2
sevenptvlbpkdzpp8tnlvkdjjpbt
qgoneighteighttgrdmljtzbblrtskvfivevbbp1
ninethreejbxseven392
86pbrnhhhpn
sevenonenine5bcqrttts6fourthree
4seventwo5ngnbkqftzdfive4lhsthree
36seven97klhbqbpgninerb
813eight
ncbfctqlsnfive1brqpthree4
ksbsddjcknsevensix293three
rljzzbvd3zkmbpjt9eightninesnlrsone
97ninesevenrhchvppnztvfbfpkzrbcone
sevendxbninefour2fourclmln
1rdtwofjvdllht5eightsixfourbl"""

# %%
print(f"Calibration: {calibration_value(puzzle_input)}")

# %%
def get_day1_input():
    with open("day1_input.txt") as f:
        data = f.read()

    return data

print(f"{get_day1_input()}")

# %%
sample_text="""two1nine
eightwothree
abcone2threexyz
xtwone3four
4nineeightseven2
zoneight234
7pqrstsixteen"""

print(f"{sample_text=}")
# Out:
# sample_text='two1nine\neightwothree\nabcone2threexyz\nxtwone3four\n4nineeightseven2\nzoneight234\n7pqrstsixteen'

# %%
import re

def find_int_words(line):
  word_index = {}
  word_list = [["one", "1"], ["two", "2"], ["three", "3"], ["four", "4"], ["five", "5"], ["six", "6"], ["seven", "7"], ["eight", "8"], ["nine", "9"]]

  for num_word in word_list:
    print(f"{num_word=}")
    for num in num_word:
      #word_location = line.find(num)
      word_matches = re.finditer(num, line)
      for word_match in word_matches:
        num = num_word[1]
        word_location = word_match.start()
        word_index[word_location] =int(num)
        print(f"{num=}, at {word_location=}, {num=}, ")

  return word_index

def get_first_and_last(words_dict):
  return [words_dict[min(words_dict)], words_dict[max(words_dict)]]




def get_calibration2(text):
  calibration_value = 0
  lines=text.splitlines()
  print(f"{lines=}")
  for line in lines:
    print(f"{line=}")
    numbers = find_int_words(line)
    first_and_last = get_first_and_last(numbers)
    line_val = 10*first_and_last[0] + first_and_last[1]
    print(f"{numbers=} {first_and_last=} {line_val=}")
    calibration_value += line_val
    print(f"Calibration: {calibration_value=}")
  return calibration_value

get_calibration2(sample_text)
# Out:
# lines=['two1nine', 'eightwothree', 'abcone2threexyz', 'xtwone3four', '4nineeightseven2', 'zoneight234', '7pqrstsixteen']
# line='two1nine'
# num_word=['one', '1']
# num='1', at word_location=3, num='1',
# num_word=['two', '2']
# num='2', at word_location=0, num='2',
# num_word=['three', '3']
# num_word=['four', '4']
# num_word=['five', '5']
# num_word=['six', '6']
# num_word=['seven', '7']
# num_word=['eight', '8']
# num_word=['nine', '9']
# num='9', at word_location=4, num='9',
# numbers={3: 1, 0: 2, 4: 9} first_and_last=[2, 9] line_val=29
# Calibration: calibration_value=29
# line='eightwothree'
# num_word=['one', '1']
# num_word=['two', '2']
# num='2', at word_location=4, num='2',
# num_word=['three', '3']
# num='3', at word_location=7, num='3',
# num_word=['four', '4']
# num_word=['five', '5']
# num_word=['six', '6']
# num_word=['seven', '7']
# num_word=['eight', '8']
# num='8', at word_location=0, num='8',
# num_word=['nine', '9']
# numbers={4: 2, 7: 3, 0: 8} first_and_last=[8, 3] line_val=83
# Calibration: calibration_value=112
# line='abcone2threexyz'
# num_word=['one', '1']
# num='1', at word_location=3, num='1',
# num_word=['two', '2']
# num='2', at word_location=6, num='2',
# num_word=['three', '3']
# num='3', at word_location=7, num='3',
# num_word=['four', '4']
# num_word=['five', '5']
# num_word=['six', '6']
# num_word=['seven', '7']
# num_word=['eight', '8']
# num_word=['nine', '9']
# numbers={3: 1, 6: 2, 7: 3} first_and_last=[1, 3] line_val=13
# Calibration: calibration_value=125
# line='xtwone3four'
# num_word=['one', '1']
# num='1', at word_location=3, num='1',
# num_word=['two', '2']
# num='2', at word_location=1, num='2',
# num_word=['three', '3']
# num='3', at word_location=6, num='3',
# num_word=['four', '4']
# num='4', at word_location=7, num='4',
# num_word=['five', '5']
# num_word=['six', '6']
# num_word=['seven', '7']
# num_word=['eight', '8']
# num_word=['nine', '9']
# numbers={3: 1, 1: 2, 6: 3, 7: 4} first_and_last=[2, 4] line_val=24
# Calibration: calibration_value=149
# line='4nineeightseven2'
# num_word=['one', '1']
# num_word=['two', '2']
# num='2', at word_location=15, num='2',
# num_word=['three', '3']
# num_word=['four', '4']
# num='4', at word_location=0, num='4',
# num_word=['five', '5']
# num_word=['six', '6']
# num_word=['seven', '7']
# num='7', at word_location=10, num='7',
# num_word=['eight', '8']
# num='8', at word_location=5, num='8',
# num_word=['nine', '9']
# num='9', at word_location=1, num='9',
# numbers={15: 2, 0: 4, 10: 7, 5: 8, 1: 9} first_and_last=[4, 2] line_val=42
# Calibration: calibration_value=191
# line='zoneight234'
# num_word=['one', '1']
# num='1', at word_location=1, num='1',
# num_word=['two', '2']
# num='2', at word_location=8, num='2',
# num_word=['three', '3']
# num='3', at word_location=9, num='3',
# num_word=['four', '4']
# num='4', at word_location=10, num='4',
# num_word=['five', '5']
# num_word=['six', '6']
# num_word=['seven', '7']
# num_word=['eight', '8']
# num='8', at word_location=3, num='8',
# num_word=['nine', '9']
# numbers={1: 1, 8: 2, 9: 3, 10: 4, 3: 8} first_and_last=[1, 4] line_val=14
# Calibration: calibration_value=205
# line='7pqrstsixteen'
# num_word=['one', '1']
# num_word=['two', '2']
# num_word=['three', '3']
# num_word=['four', '4']
# num_word=['five', '5']
# num_word=['six', '6']
# num='6', at word_location=6, num='6',
# num_word=['seven', '7']
# num='7', at word_location=0, num='7',
# num_word=['eight', '8']
# num_word=['nine', '9']
# numbers={6: 6, 0: 7} first_and_last=[7, 6] line_val=76
# Calibration: calibration_value=281
# 281

# %%
print(f"Calbration: {get_calibration2(puzzle_input)}")
# Out:
num='5',
# num_word=['six', '6']
# num_word=['seven', '7']
# num_word=['eight', '8']
# num_word=['nine', '9']
# numbers={16: 3, 12: 4, 4: 5} first_and_last=[5, 3] line_val=53
# Calibration: calibration_value=133
# line='tn5eightfncnzcdtthree8'
# num_word=['one', '1']
# num_word=['two', '2']
# num_word=['three', '3']
# num='3', at word_location=16, num='3',
# num_word=['four', '4']
# num_word=['five', '5']
# num='5', at word_location=2, num='5',
# num_word=['six', '6']
# num_word=['seven', '7']
# num_word=['eight', '8']
# num='8', at word_location=3, num='8',
# num='8', at word_location=21, num='8',
# num_word=['nine', '9']
# numbers={16: 3, 2: 5, 3: 8, 21: 8} first_and_last=[5, 8] line_val=58
# Calibration: calibration_value=191
# line='kpmrk5flx'
# num_word=['one', '1']
# num_word=['two', '2']
# num_word=['three', '3']
# num_word=['four', '4']
# num_word=['five', '5']
# num='5', at word_location=5, num='5',
# num_word=['six', '6']
# num_word=['seven', '7']
# num_word=['eight', '8']
# num_word=['nine', '9']
# numbers={5: 5} first_and_last=[5, 5] line_val=55
# Calibration: calibration_value=246
# line='fkxxqxdfsixgthreepvzjxrkcfk6twofour'
# num_word=['one', '1']
# num_word=['two', '2']
# num='2', at word_location=28, num='2',
# num_word=['three', '3']
# num='3', at word_location=12, num='3',
# num_word=['four', '4']
# num='4', at word_location=31, num='4',
# num_word=['five', '5']
# num_word=['six', '6']
# num='6', at word_location=8, num='6',
# num='6', at word_location=27, num='6',
# num_word=['seven', '7']
# num_word=['eight', '8']
# num_word=['nine', '9']
# numbers={28: 2, 12: 3, 31: 4, 8: 6, 27: 6} first_and_last=[6, 4] line_val=64
# Calibration: calibration_value=310
# line='dqbx6six5twoone'
# num_word=['one', '1']
# num='1', at word_location=12, num='1',
# num_word=['two', '2']
# num='2', at word_location=9, num='2',
# num_word=['three', '3']
# num_word=['four', '4']
# num_word=['five', '5']
# num='5', at word_location=8, num='5',
# num_word=['six', '6']
# num='6', at word_location=5, num='6',
# num='6', at word_location=4, num='6',
# num_word=['seven', '7']
# num_word=['eight', '8']
# num_word=['nine', '9']
# numbers={12: 1, 9: 2, 8: 5, 5: 6, 4: 6} first_and_last=[6, 1] line_val=61
# Calibration: calibration_value=371
# line='glmsckj2bvmts1spctnjrtqhmbxzq'
# num_word=['one', '1']
# num='1', at word_location=13, num='1',
# num_word=['two', '2']
# num='2', at word_location=7, num='2',
# num_word=['three', '3']
# num_word=['four', '4']
# num_word=['five', '5']
# num_word=['six', '6']
# num_word=['seven', '7']
# num_word=['eight', '8']
# num_word=['nine', '9']
# numbers={13: 1, 7: 2} first_and_last=[2, 1] line_val=21
# Calibration: calibration_value=392
# line='7sixthreerzmpbffcx'
# num_word=['one', '1']
# num_word=['two', '2']
# num_word=['three', '3']
# num='3', at word_location=4, num='3',
# num_word=['four', '4']
# num_word=['five', '5']
# num_word=['six', '6']
# num='6', at word_location=1, num='6',
# num_word=['seven', '7']
# num='7', at word_location=0, num='7',
# num_word=['eight', '8']
# num_word=['nine', '9']
# numbers={4: 3, 1: 6, 0: 7} first_and_last=[7, 3] line_val=73
# Calibration: calibration_value=465
# line='zhss9gfxfgmrmzthreefivevpkljfourtwoeight'
# num_word=['one', '1']
# num_word=['two', '2']
# num='2', at word_location=32, num='2',
# num_word=['three', '3']
# num='3', at word_location=14, num='3',
# num_word=['four', '4']
# num='4', at word_location=28, num='4',
# num_word=['five', '5']
# num='5', at word_location=19, num='5',
# num_word=['six', '6']
# num_word=['seven', '7']
# num_word=['eight', '8']
# num='8', at word_location=35, num='8',
# num_word=['nine', '9']
# num='9', at word_location=4, num='9',
# numbers={32: 2, 14: 3, 28: 4, 19: 5, 35: 8, 4: 9} first_and_last=[9, 8] line_val=98
# Calibration: calibration_value=563
# line='6tfzvrbkfour'
# num_word=['one', '1']
# num_word=['two', '2']
# num_word=['three', '3']
# num_word=['four', '4']
# num='4', at word_location=8, num='4',
# num_word=['five', '5']
# num_word=['six', '6']
# num='6', at word_location=0, num='6',
# num_word=['seven', '7']
# num_word=['eight', '8']
# num_word=['nine', '9']
# numbers={8: 4, 0: 6} first_and_last=[6, 4] line_val=64
# Calibration: calibration_value=627
# line='sevenfive66five851'
# num_word=['one', '1']
# num='1', at word_location=17, num='1',
# num_word=['two', '2']
# num_word=['three', '3']
# num_word=['four', '4']
# num_word=['five', '5']
# num='5', at word_location=5, num='5',
# num='5', at word_location=11, num='5',
# num='5', at word_location=16, num='5',
# num_word=['six', '6']
# num='6', at word_location=9, num='6',
# num='6', at word_location=10, num='6',
# num_word=['seven', '7']
# num='7', at word_location=0, num='7',
# num_word=['eight', '8']
# num='8', at word_location=15, num='8',
# num_word=['nine', '9']
# numbers={17: 1, 5: 5, 11: 5, 16: 5, 9: 6, 10: 6, 0: 7, 15: 8} first_and_last=[7, 1] line_val=71
# Calibration: calibration_value=698
# line='drsgdrrgscqmsggrgq1fsqjhtkkrltt'
# num_word=['one', '1']
# num='1', at word_location=18, num='1',
# num_word=['two', '2']
# num_word=['three', '3']
# num_word=['four', '4']
# num_word=['five', '5']
# num_word=['six', '6']
# num_word=['seven', '7']
# num_word=['eight', '8']
# num_word=['nine', '9']
# numbers={18: 1} first_and_last=[1, 1] line_val=11
# Calibration: calibration_value=709
# line='3ftptvzhvrm5'
# num_word=['one', '1']
# num_word=['two', '2']
# num_word=['three', '3']
# num='3', at word_location=0, num='3',
# num_word=['four', '4']
# num_word=['five', '5']
# num='5', at word_location=11, num='5',
# num_word=['six', '6']
# num_word=['seven', '7']
# num_word=['eight', '8']
# num_word=['nine', '9']
# numbers={0: 3, 11: 5} first_and_last=[3, 5] line_val=35
# Calibration: calibration_value=744
# line='twoeightninemfsztp2gbqkpgqvzt6threekcdcp'
# num_word=['one', '1']
# num_word=['two', '2']
# num='2', at word_location=0, num='2',
# num='2', at word_location=18, num='2',
# num_word=['three', '3']
# num='3', at word_location=30, num='3',
# num_word=['four', '4']
# num_word=['five', '5']
# num_word=['six', '6']
# num='6', at word_location=29, num='6',
# num_word=['seven', '7']
# num_word=['eight', '8']
# num='8', at word_location=3, num='8',
# num_word=['nine', '9']
# num='9', at word_location=8, num='9',
# numbers={0: 2, 18: 2, 30: 3, 29: 6, 3: 8, 8: 9} first_and_last=[2, 3] line_val=23
# Calibration: calibration_value=767
# line='four156'
# num_word=['one', '1']
# num='1', at word_location=4, num='1',
# num_word=['two', '2']
# num_word=['three', '3']
# num_word=['four', '4']
# num='4', at word_location=0, num='4',
# num_word=['five', '5']
# num='5', at word_location=5, num='5',
# num_word=['six', '6']
# num='6', at word_location=6, num='6',
# num_word=['seven', '7']
# num_word=['eight', '8']
# num_word=['nine', '9']
# numbers={4: 1, 0: 4, 5: 5, 6: 6} first_and_last=[4, 6] line_val=46
# Calibration: calibration_value=813
# line='959157fourfive'
# num_word=['one', '1']
# num='1', at word_location=3, num='1',
# num_word=['two', '2']
# num_word=['three', '3']
# num_word=['four', '4']
# num='4', at word_location=6, num='4',
# num_word=['five', '5']
# num='5', at word_location=10, num='5',
# num='5', at word_location=1, num='5',
# num='5', at word_location=4, num='5',
# num_word=['six', '6']
# num_word=['seven', '7']
# num='7', at word_location=5, num='7',
# num_word=['eight', '8']
# num_word=['nine', '9']
# num='9', at word_location=0, num='9',
# num='9', at word_location=2, num='9',
# numbers={3: 1, 6: 4, 10: 5, 1: 5, 4: 5, 5: 7, 0: 9, 2: 9} first_and_last=[9, 5] line_val=95
# Calibration: calibration_value=908
# line='sixthreetwo87one7fourdbczdbjcc'
# num_word=['one', '1']
# num='1', at word_location=13, num='1',
# num_word=['two', '2']
# num='2', at word_location=8, num='2',
# num_word=['three', '3']
# num='3', at word_location=3, num='3',
# num_word=['four', '4']
# num='4', at word_location=17, num='4',
# num_word=['five', '5']
# num_word=['six', '6']
# num='6', at word_location=0, num='6',
# num_word=['seven', '7']
# num='7', at word_location=12, num='7',
# num='7', at word_location=16, num='7',
# num_word=['eight', '8']
# num='8', at word_location=11, num='8',
# num_word=['nine', '9']
# numbers={13: 1, 8: 2, 3: 3, 17: 4, 0: 6, 12: 7, 16: 7, 11: 8} first_and_last=[6, 4] line_val=64
# Calibration: calibration_value=972
# line='lshzfive7'
# num_word=['one', '1']
# num_word=['two', '2']
# num_word=['three', '3']
# num_word=['four', '4']
# num_word=['five', '5']
# num='5', at word_location=4, num='5',
# num_word=['six', '6']
# num_word=['seven', '7']
# num='7', at word_location=8, num='7',
# num_word=['eight', '8']
# num_word=['nine', '9']
# numbers={4: 5, 8: 7} first_and_last=[5, 7] line_val=57
# Calibration: calibration_value=1029
# line='38ninethreethreesevensixeight'
# num_word=['one', '1']
# num_word=['two', '2']
# num_word=['three', '3']
# num='3', at word_location=6, num='3',
# num='3', at word_location=11, num='3',
# num='3', at word_location=0, num='3',
# num_word=['four', '4']
# num_word=['five', '5']
# num_word=['six', '6']
# num='6', at word_location=21, num='6',
# num_word=['seven', '7']
# num='7', at word_location=16, num='7',
# num_word=['eight', '8']
# num='8', at word_location=24, num='8',
# num='8', at word_location=1, num='8',
# num_word=['nine', '9']
# num='9', at word_location=2, num='9',
# numbers={6: 3, 11: 3, 0: 3, 21: 6, 16: 7, 24: 8, 1: 8, 2: 9} first_and_last=[3, 8] line_val=38
# Calibration: calibration_value=1067
# line='z39hpppnncfivenbkc'
# num_word=['one', '1']
# num_word=['two', '2']
# num_word=['three', '3']
# num='3', at word_location=1, num='3',
# num_word=['four', '4']
# num_word=['five', '5']
# num='5', at word_location=10, num='5',
# num_word=['six', '6']
# num_word=['seven', '7']
# num_word=['eight', '8']
# num_word=['nine', '9']
# num='9', at word_location=2, num='9',
# numbers={1: 3, 10: 5, 2: 9} first_and_last=[3, 5] line_val=35
# Calibration: calibration_value=1102
# line='9ninefivevnbrrfrfjfivetwo'
# num_word=['one', '1']
# num_word=['two', '2']
# num='2', at word_location=22, num='2',
# num_word=['three', '3']
# num_word=['four', '4']
# num_word=['five', '5']
# num='5', at word_location=5, num='5',
# num='5', at word_location=18, num='5',
# num_word=['six', '6']
# num_word=['seven', '7']
# num_word=['eight', '8']
# num_word=['nine', '9']
# num='9', at word_location=1, num='9',
# num='9', at word_location=0, num='9',
# numbers={22: 2, 5: 5, 18: 5, 1: 9, 0: 9} first_and_last=[9, 2] line_val=92
# Calibration: calibration_value=1194
# line='fzgnjsz2nine9'
# num_word=['one', '1']
# num_word=['two', '2']
# num='2', at word_location=7, num='2',
# num_word=['three', '3']
# num_word=['four', '4']
# num_word=['five', '5']
# num_word=['six', '6']
# num_word=['seven', '7']
# num_word=['eight', '8']
# num_word=['nine', '9']
# num='9', at word_location=8, num='9',
# num='9', at word_location=12, num='9',
# numbers={7: 2, 8: 9, 12: 9} first_and_last=[2, 9] line_val=29
# Calibration: calibration_value=1223
# line='fnhksixfour1six81'
# num_word=['one', '1']
# num='1', at word_location=11, num='1',
# num='1', at word_location=16, num='1',
# num_word=['two', '2']
# num_word=['three', '3']
# num_word=['four', '4']
# num='4', at word_location=7, num='4',
# num_word=['five', '5']
# num_word=['six', '6']
# num='6', at word_location=4, num='6',
# num='6', at word_location=12, num='6',
# num_word=['seven', '7']
# num_word=['eight', '8']
# num='8', at word_location=15, num='8',
# num_word=['nine', '9']
# numbers={11: 1, 16: 1, 7: 4, 4: 6, 12: 6, 15: 8} first_and_last=[6, 1] line_val=61
# Calibration: calibration_value=1284
# line='vkkxbgcqzqflgsvgkkkpfp9five58stsix'
# num_word=['one', '1']
# num_word=['two', '2']
# num_word=['three', '3']
# num_word=['four', '4']
# num_word=['five', '5']
# num='5', at word_location=23, num='5',
# num='5', at word_location=27, num='5',
# num_word=['six', '6']
# num='6', at word_location=31, num='6',
# num_word=['seven', '7']
# num_word=['eight', '8']
# num='8', at word_location=28, num='8',
# num_word=['nine', '9']
# num='9', at word_location=22, num='9',
# numbers={23: 5, 27: 5, 31: 6, 28: 8, 22: 9} first_and_last=[9, 6] line_val=96
# Calibration: calibration_value=1380
# line='eight26sixsghd'
# num_word=['one', '1']
# num_word=['two', '2']
# num='2', at word_location=5, num='2',
# num_word=['three', '3']
# num_word=['four', '4']
# num_word=['five', '5']
# num_word=['six', '6']
# num='6', at word_location=7, num='6',
# num='6', at word_location=6, num='6',
# num_word=['seven', '7']
# num_word=['eight', '8']
# num='8', at word_location=0, num='8',
# num_word=['nine', '9']
# numbers={5: 2, 7: 6, 6: 6, 0: 8} first_and_last=[8, 6] line_val=86
# Calibration: calibration_value=1466
# line='7zvrjkcrrgbsix'
# num_word=['one', '1']
# num_word=['two', '2']
# num_word=['three', '3']
# num_word=['four', '4']
# num_word=['five', '5']
# num_word=['six', '6']
# num='6', at word_location=11, num='6',
# num_word=['seven', '7']
# num='7', at word_location=0, num='7',
# num_word=['eight', '8']
# num_word=['nine', '9']
# numbers={11: 6, 0: 7} first_and_last=[7, 6] line_val=76
# Calibration: calibration_value=1542
# line='tgdf38fpcssixeightcjtfour'
# num_word=['one', '1']
# num_word=['two', '2']
# num_word=['three', '3']
# num='3', at word_location=4, num='3',
# num_word=['four', '4']
# num='4', at word_location=21, num='4',
# num_word=['five', '5']
# num_word=['six', '6']
# num='6', at word_location=10, num='6',
# num_word=['seven', '7']
# num_word=['eight', '8']
# num='8', at word_location=13, num='8',
# num='8', at word_location=5, num='8',
# num_word=['nine', '9']
# numbers={4: 3, 21: 4, 10: 6, 13: 8, 5: 8} first_and_last=[3, 4] line_val=34
# Calibration: calibration_value=1576
# line='tcrqkxkptrtt5fdblcldfoursix'
# num_word=['one', '1']
# num_word=['two', '2']
# num_word=['three', '3']
# num_word=['four', '4']
# num='4', at word_location=20, num='4',
# num_word=['five', '5']
# num='5', at word_location=12, num='5',
# num_word=['six', '6']
# num='6', at word_location=24, num='6',
# num_word=['seven', '7']
# num_word=['eight', '8']
# num_word=['nine', '9']
# numbers={20: 4, 12: 5, 24: 6} first_and_last=[5, 6] line_val=56
# Calibration: calibration_value=1632
# line='9qpmknkbtxsfourd'
# num_word=['one', '1']
# num_word=['two', '2']
# num_word=['three', '3']
# num_word=['four', '4']
# num='4', at word_location=11, num='4',
# num_word=['five', '5']
# num_word=['six', '6']
# num_word=['seven', '7']
# num_word=['eight', '8']
# num_word=['nine', '9']
# num='9', at word_location=0, num='9',
# numbers={11: 4, 0: 9} first_and_last=[9, 4] line_val=94
# Calibration: calibration_value=1726
# line='8948twosix9three8'
# num_word=['one', '1']
# num_word=['two', '2']
# num='2', at word_location=4, num='2',
# num_word=['three', '3']
# num='3', at word_location=11, num='3',
# num_word=['four', '4']
# num='4', at word_location=2, num='4',
# num_word=['five', '5']
# num_word=['six', '6']
# num='6', at word_location=7, num='6',
# num_word=['seven', '7']
# num_word=['eight', '8']
# num='8', at word_location=0, num='8',
# num='8', at word_location=3, num='8',
# num='8', at word_location=16, num='8',
# num_word=['nine', '9']
# num='9', at word_location=1, num='9',
# num='9', at word_location=10, num='9',
# numbers={4: 2, 11: 3, 2: 4, 7: 6, 0: 8, 3: 8, 16: 8, 1: 9, 10: 9} first_and_last=[8, 8] line_val=88
# Calibration: calibration_value=1814
# line='vpbjslqkpbxkpfiveeight1mzjmhfzl'
# num_word=['one', '1']
# num='1', at word_location=22, num='1',
# num_word=['two', '2']
# num_word=['three', '3']
# num_word=['four', '4']
# num_word=['five', '5']
# num='5', at word_location=13, num='5',
# num_word=['six', '6']
# num_word=['seven', '7']
# num_word=['eight', '8']
# num='8', at word_location=17, num='8',
# num_word=['nine', '9']
# numbers={22: 1, 13: 5, 17: 8} first_and_last=[5, 1] line_val=51
# Calibration: calibration_value=1865
# line='187jccxsbqtcjtwo1'
# num_word=['one', '1']
# num='1', at word_location=0, num='1',
# num='1', at word_location=16, num='1',
# num_word=['two', '2']
# num='2', at word_location=13, num='2',
# num_word=['three', '3']
# num_word=['four', '4']
# num_word=['five', '5']
# num_word=['six', '6']
# num_word=['seven', '7']
# num='7', at word_location=2, num='7',
# num_word=['eight', '8']
# num='8', at word_location=1, num='8',
# num_word=['nine', '9']
# numbers={0: 1, 16: 1, 13: 2, 2: 7, 1: 8} first_and_last=[1, 1] line_val=11
# Calibration: calibration_value=1876
# line='sixfiveonefour637three'
# num_word=['one', '1']
# num='1', at word_location=7, num='1',
# num_word=['two', '2']
# num_word=['three', '3']
# num='3', at word_location=17, num='3',
# num='3', at word_location=15, num='3',
# num_word=['four', '4']
# num='4', at word_location=10, num='4',
# num_word=['five', '5']
# num='5', at word_location=3, num='5',
# num_word=['six', '6']
# num='6', at word_location=0, num='6',
# num='6', at word_location=14, num='6',
# num_word=['seven', '7']
# num='7', at word_location=16, num='7',
# num_word=['eight', '8']
# num_word=['nine', '9']
# numbers={7: 1, 17: 3, 15: 3, 10: 4, 3: 5, 0: 6, 14: 6, 16: 7} first_and_last=[6, 3] line_val=63
# Calibration: calibration_value=1939
# line='stjbeightsixdfnsppjrgfdggqzjx6cplvznllsgtwo'
# num_word=['one', '1']
# num_word=['two', '2']
# num='2', at word_location=40, num='2',
# num_word=['three', '3']
# num_word=['four', '4']
# num_word=['five', '5']
# num_word=['six', '6']
# num='6', at word_location=9, num='6',
# num='6', at word_location=29, num='6',
# num_word=['seven', '7']
# num_word=['eight', '8']
# num='8', at word_location=4, num='8',
# num_word=['nine', '9']
# numbers={40: 2, 9: 6, 29: 6, 4: 8} first_and_last=[8, 2] line_val=82
# Calibration: calibration_value=2021
# line='3lrznqgc85seven3'
# num_word=['one', '1']
# num_word=['two', '2']
# num_word=['three', '3']
# num='3', at word_location=0, num='3',
# num='3', at word_location=15, num='3',
# num_word=['four', '4']
# num_word=['five', '5']
# num='5', at word_location=9, num='5',
# num_word=['six', '6']
# num_word=['seven', '7']
# num='7', at word_location=10, num='7',
# num_word=['eight', '8']
# num='8', at word_location=8, num='8',
# num_word=['nine', '9']
# numbers={0: 3, 15: 3, 9: 5, 10: 7, 8: 8} first_and_last=[3, 3] line_val=33
# Calibration: calibration_value=2054
# line='1eightfourfourmgxhdp51slrszbxmhthree'
# num_word=['one', '1']
# num='1', at word_location=0, num='1',
# num='1', at word_location=21, num='1',
# num_word=['two', '2']
# num_word=['three', '3']
# num='3', at word_location=31, num='3',
# num_word=['four', '4']
# num='4', at word_location=6, num='4',
# num='4', at word_location=10, num='4',
# num_word=['five', '5']
# num='5', at word_location=20, num='5',
# num_word=['six', '6']
# num_word=['seven', '7']
# num_word=['eight', '8']
# num='8', at word_location=1, num='8',
# num_word=['nine', '9']
# numbers={0: 1, 21: 1, 31: 3, 6: 4, 10: 4, 20: 5, 1: 8} first_and_last=[1, 3] line_val=13
# Calibration: calibration_value=2067
# line='two3hj'
# num_word=['one', '1']
# num_word=['two', '2']
# num='2', at word_location=0, num='2',
# num_word=['three', '3']
# num='3', at word_location=3, num='3',
# num_word=['four', '4']
# num_word=['five', '5']
# num_word=['six', '6']
# num_word=['seven', '7']
# num_word=['eight', '8']
# num_word=['nine', '9']
# numbers={0: 2, 3: 3} first_and_last=[2, 3] line_val=23
# Calibration: calibration_value=2090
# line='zgnoneightseveneightseven5d2fivefourjp'
# num_word=['one', '1']
# num='1', at word_location=3, num='1',
# num_word=['two', '2']
# num='2', at word_location=27, num='2',
# num_word=['three', '3']
# num_word=['four', '4']
# num='4', at word_location=32, num='4',
# num_word=['five', '5']
# num='5', at word_location=28, num='5',
# num='5', at word_location=25, num='5',
# num_word=['six', '6']
# num_word=['seven', '7']
# num='7', at word_location=10, num='7',
# num='7', at word_location=20, num='7',
# num_word=['eight', '8']
# num='8', at word_location=5, num='8',
# num='8', at word_location=15, num='8',
# num_word=['nine', '9']
# numbers={3: 1, 27: 2, 32: 4, 28: 5, 25: 5, 10: 7, 20: 7, 5: 8, 15: 8} first_and_last=[1, 4] line_val=14
# Calibration: calibration_value=2104
# line='ldjzhninetwokxlkbbzcngssdqphlrc51'
# num_word=['one', '1']
# num='1', at word_location=32, num='1',
# num_word=['two', '2']
# num='2', at word_location=9, num='2',
# num_word=['three', '3']
# num_word=['four', '4']
# num_word=['five', '5']
# num='5', at word_location=31, num='5',
# num_word=['six', '6']
# num_word=['seven', '7']
# num_word=['eight', '8']
# num_word=['nine', '9']
# num='9', at word_location=5, num='9',
# numbers={32: 1, 9: 2, 31: 5, 5: 9} first_and_last=[9, 1] line_val=91
# Calibration: calibration_value=2195
# line='qvhtfhmltt61lss'
# num_word=['one', '1']
# num='1', at word_location=11, num='1',
# num_word=['two', '2']
# num_word=['three', '3']
# num_word=['four', '4']
# num_word=['five', '5']
# num_word=['six', '6']
# num='6', at word_location=10, num='6',
# num_word=['seven', '7']
# num_word=['eight', '8']
# num_word=['nine', '9']
# numbers={11: 1, 10: 6} first_and_last=[6, 1] line_val=61
# Calibration: calibration_value=2256
# line='lfmnhxmhschzrtntwotwo7twovkl8two'
# num_word=['one', '1']
# num_word=['two', '2']
# num='2', at word_location=15, num='2',
# num='2', at word_location=18, num='2',
# num='2', at word_location=22, num='2',
# num='2', at word_location=29, num='2',
# num_word=['three', '3']
# num_word=['four', '4']
# num_word=['five', '5']
# num_word=['six', '6']
# num_word=['seven', '7']
# num='7', at word_location=21, num='7',
# num_word=['eight', '8']
# num='8', at word_location=28, num='8',
# num_word=['nine', '9']
# numbers={15: 2, 18: 2, 22: 2, 29: 2, 21: 7, 28: 8} first_and_last=[2, 2] line_val=22
# Calibration: calibration_value=2278
# line='vrpplrtqxvssgnvdf8'
# num_word=['one', '1']
# num_word=['two', '2']
# num_word=['three', '3']
# num_word=['four', '4']
# num_word=['five', '5']
# num_word=['six', '6']
# num_word=['seven', '7']
# num_word=['eight', '8']
# num='8', at word_location=17, num='8',
# num_word=['nine', '9']
# numbers={17: 8} first_and_last=[8, 8] line_val=88
# Calibration: calibration_value=2366
# line='dzrnnphfl451'
# num_word=['one', '1']
# num='1', at word_location=11, num='1',
# num_word=['two', '2']
# num_word=['three', '3']
# num_word=['four', '4']
# num='4', at word_location=9, num='4',
# num_word=['five', '5']
# num='5', at word_location=10, num='5',
# num_word=['six', '6']
# num_word=['seven', '7']
# num_word=['eight', '8']
# num_word=['nine', '9']
# numbers={11: 1, 9: 4, 10: 5} first_and_last=[4, 1] line_val=41
# Calibration: calibration_value=2407
# line='two7pgbsixlkmseven'
# num_word=['one', '1']
# num_word=['two', '2']
# num='2', at word_location=0, num='2',
# num_word=['three', '3']
# num_word=['four', '4']
# num_word=['five', '5']
# num_word=['six', '6']
# num='6', at word_location=7, num='6',
# num_word=['seven', '7']
# num='7', at word_location=13, num='7',
# num='7', at word_location=3, num='7',
# num_word=['eight', '8']
# num_word=['nine', '9']
# numbers={0: 2, 7: 6, 13: 7, 3: 7} first_and_last=[2, 7] line_val=27
# Calibration: calibration_value=2434
# line='rplqnj5oneseven'
# num_word=['one', '1']
# num='1', at word_location=7, num='1',
# num_word=['two', '2']
# num_word=['three', '3']
# num_word=['four', '4']
# num_word=['five', '5']
# num='5', at word_location=6, num='5',
# num_word=['six', '6']
# num_word=['seven', '7']
# num='7', at word_location=10, num='7',
# num_word=['eight', '8']
# num_word=['nine', '9']
# numbers={7: 1, 6: 5, 10: 7} first_and_last=[5, 7] line_val=57
# Calibration: calibration_value=2491
# line='2fourfourchd7'
# num_word=['one', '1']
# num_word=['two', '2']
# num='2', at word_location=0, num='2',
# num_word=['three', '3']
# num_word=['four', '4']
# num='4', at word_location=1, num='4',
# num='4', at word_location=5, num='4',
# num_word=['five', '5']
# num_word=['six', '6']
# num_word=['seven', '7']
# num='7', at word_location=12, num='7',
# num_word=['eight', '8']
# num_word=['nine', '9']
# numbers={0: 2, 1: 4, 5: 4, 12: 7} first_and_last=[2, 7] line_val=27
# Calibration: calibration_value=2518
# line='threesixdpslzdft3hq'
# num_word=['one', '1']
# num_word=['two', '2']
# num_word=['three', '3']
# num='3', at word_location=0, num='3',
# num='3', at word_location=16, num='3',
# num_word=['four', '4']
# num_word=['five', '5']
# num_word=['six', '6']
# num='6', at word_location=5, num='6',
# num_word=['seven', '7']
# num_word=['eight', '8']
# num_word=['nine', '9']
# numbers={0: 3, 16: 3, 5: 6} first_and_last=[3, 3] line_val=33
# Calibration: calibration_value=2551
# line='three4bqhlckrlgeight2lbdvcggfqd'
# num_word=['one', '1']
# num_word=['two', '2']
# num='2', at word_location=20, num='2',
# num_word=['three', '3']
# num='3', at word_location=0, num='3',
# num_word=['four', '4']
# num='4', at word_location=5, num='4',
# num_word=['five', '5']
# num_word=['six', '6']
# num_word=['seven', '7']
# num_word=['eight', '8']
# num='8', at word_location=15, num='8',
# num_word=['nine', '9']
# numbers={20: 2, 0: 3, 5: 4, 15: 8} first_and_last=[3, 2] line_val=32
# Calibration: calibration_value=2583
# line='ninefive6zqhgfhfdnk'
# num_word=['one', '1']
# num_word=['two', '2']
# num_word=['three', '3']
# num_word=['four', '4']
# num_word=['five', '5']
# num='5', at word_location=4, num='5',
# num_word=['six', '6']
# num='6', at word_location=8, num='6',
# num_word=['seven', '7']
# num_word=['eight', '8']
# num_word=['nine', '9']
# num='9', at word_location=0, num='9',
# numbers={4: 5, 8: 6, 0: 9} first_and_last=[9, 6] line_val=96
# Calibration: calibration_value=2679
# line='2one9five2'
# num_word=['one', '1']
# num='1', at word_location=1, num='1',
# num_word=['two', '2']
# num='2', at word_location=0, num='2',
# num='2', at word_location=9, num='2',
# num_word=['three', '3']
# num_word=['four', '4']
# num_word=['five', '5']
# num='5', at word_location=5, num='5',
# num_word=['six', '6']
# num_word=['seven', '7']
# num_word=['eight', '8']
# num_word=['nine', '9']
# num='9', at word_location=4, num='9',
# numbers={1: 1, 0: 2, 9: 2, 5: 5, 4: 9} first_and_last=[2, 2] line_val=22
# Calibration: calibration_value=2701
# line='1ftsjdfmnkvlx9seven'
# num_word=['one', '1']
# num='1', at word_location=0, num='1',
# num_word=['two', '2']
# num_word=['three', '3']
# num_word=['four', '4']
# num_word=['five', '5']
# num_word=['six', '6']
# num_word=['seven', '7']
# num='7', at word_location=14, num='7',
# num_word=['eight', '8']
# num_word=['nine', '9']
# num='9', at word_location=13, num='9',
# numbers={0: 1, 14: 7, 13: 9} first_and_last=[1, 7] line_val=17
# Calibration: calibration_value=2718
# line='four1zsztlvnhcjtvmrlthree4kpztfzqjtdplfxpqlskh'
# num_word=['one', '1']
# num='1', at word_location=4, num='1',
# num_word=['two', '2']
# num_word=['three', '3']
# num='3', at word_location=20, num='3',
# num_word=['four', '4']
# num='4', at word_location=0, num='4',
# num='4', at word_location=25, num='4',
# num_word=['five', '5']
# num_word=['six', '6']
# num_word=['seven', '7']
# num_word=['eight', '8']
# num_word=['nine', '9']
# numbers={4: 1, 20: 3, 0: 4, 25: 4} first_and_last=[4, 4] line_val=44
# Calibration: calibration_value=2762
# line='6zfrhkckfvxsixtjgtnmcx'
# num_word=['one', '1']
# num_word=['two', '2']
# num_word=['three', '3']
# num_word=['four', '4']
# num_word=['five', '5']
# num_word=['six', '6']
# num='6', at word_location=11, num='6',
# num='6', at word_location=0, num='6',
# num_word=['seven', '7']
# num_word=['eight', '8']
# num_word=['nine', '9']
# numbers={11: 6, 0: 6} first_and_last=[6, 6] line_val=66
# Calibration: calibration_value=2828
# line='eightfourcppgkrmtn3chqxgscpd1'
# num_word=['one', '1']
# num='1', at word_location=28, num='1',
# num_word=['two', '2']
# num_word=['three', '3']
# num='3', at word_location=18, num='3',
# num_word=['four', '4']
# num='4', at word_location=5, num='4',
# num_word=['five', '5']
# num_word=['six', '6']
# num_word=['seven', '7']
# num_word=['eight', '8']
# num='8', at word_location=0, num='8',
# num_word=['nine', '9']
# numbers={28: 1, 18: 3, 5: 4, 0: 8} first_and_last=[8, 1] line_val=81
# Calibration: calibration_value=2909
# line='6threegxdrv8'
# num_word=['one', '1']
# num_word=['two', '2']
# num_word=['three', '3']
# num='3', at word_location=1, num='3',
# num_word=['four', '4']
# num_word=['five', '5']
# num_word=['six', '6']
# num='6', at word_location=0, num='6',
# num_word=['seven', '7']
# num_word=['eight', '8']
# num='8', at word_location=11, num='8',
# num_word=['nine', '9']
# numbers={1: 3, 0: 6, 11: 8} first_and_last=[6, 8] line_val=68
# Calibration: calibration_value=2977
# line='mstpbscvjrc5twozjtdxhckrfsnzsdm'
# num_word=['one', '1']
# num_word=['two', '2']
# num='2', at word_location=12, num='2',
# num_word=['three', '3']
# num_word=['four', '4']
# num_word=['five', '5']
# num='5', at word_location=11, num='5',
# num_word=['six', '6']
# num_word=['seven', '7']
# num_word=['eight', '8']
# num_word=['nine', '9']
# numbers={12: 2, 11: 5} first_and_last=[5, 2] line_val=52
# Calibration: calibration_value=3029
# line='twolhntgone5'
# num_word=['one', '1']
# num='1', at word_location=8, num='1',
# num_word=['two', '2']
# num='2', at word_location=0, num='2',
# num_word=['three', '3']
# num_word=['four', '4']
# num_word=['five', '5']
# num='5', at word_location=11, num='5',
# num_word=['six', '6']
# num_word=['seven', '7']
# num_word=['eight', '8']
# num_word=['nine', '9']
# numbers={8: 1, 0: 2, 11: 5} first_and_last=[2, 5] line_val=25
# Calibration: calibration_value=3054
# line='vtrktlkrqslcdnlslthree5'
# num_word=['one', '1']
# num_word=['two', '2']
# num_word=['three', '3']
# num='3', at word_location=17, num='3',
# num_word=['four', '4']
# num_word=['five', '5']
# num='5', at word_location=22, num='5',
# num_word=['six', '6']
# num_word=['seven', '7']
# num_word=['eight', '8']
# num_word=['nine', '9']
# numbers={17: 3, 22: 5} first_and_last=[3, 5] line_val=35
# Calibration: calibration_value=3089
# line='mfkrfournine4knmmmghnsixxrmzhcsix'
# num_word=['one', '1']
# num_word=['two', '2']
# num_word=['three', '3']
# num_word=['four', '4']
# num='4', at word_location=4, num='4',
# num='4', at word_location=12, num='4',
# num_word=['five', '5']
# num_word=['six', '6']
# num='6', at word_location=21, num='6',
# num='6', at word_location=30, num='6',
# num_word=['seven', '7']
# num_word=['eight', '8']
# num_word=['nine', '9']
# num='9', at word_location=8, num='9',
# numbers={4: 4, 12: 4, 21: 6, 30: 6, 8: 9} first_and_last=[4, 6] line_val=46
# Calibration: calibration_value=3135
# line='2hfkbthree'
# num_word=['one', '1']
# num_word=['two', '2']
# num='2', at word_location=0, num='2',
# num_word=['three', '3']
# num='3', at word_location=5, num='3',
# num_word=['four', '4']
# num_word=['five', '5']
# num_word=['six', '6']
# num_word=['seven', '7']
# num_word=['eight', '8']
# num_word=['nine', '9']
# numbers={0: 2, 5: 3} first_and_last=[2, 3] line_val=23
# Calibration: calibration_value=3158
# line='nine96'
# num_word=['one', '1']
# num_word=['two', '2']
# num_word=['three', '3']
# num_word=['four', '4']
# num_word=['five', '5']
# num_word=['six', '6']
# num='6', at word_location=5, num='6',
# num_word=['seven', '7']
# num_word=['eight', '8']
# num_word=['nine', '9']
# num='9', at word_location=0, num='9',
# num='9', at word_location=4, num='9',
# numbers={5: 6, 0: 9, 4: 9} first_and_last=[9, 6] line_val=96
# Calibration: calibration_value=3254
# line='threeqglpgvxgsdfgbctdm1'
# num_word=['one', '1']
# num='1', at word_location=22, num='1',
# num_word=['two', '2']
# num_word=['three', '3']
# num='3', at word_location=0, num='3',
# num_word=['four', '4']
# num_word=['five', '5']
# num_word=['six', '6']
# num_word=['seven', '7']
# num_word=['eight', '8']
# num_word=['nine', '9']
# numbers={22: 1, 0: 3} first_and_last=[3, 1] line_val=31
# Calibration: calibration_value=3285
# line='1threechctd2tnm'
# num_word=['one', '1']
# num='1', at word_location=0, num='1',
# num_word=['two', '2']
# num='2', at word_location=11, num='2',
# num_word=['three', '3']
# num='3', at word_location=1, num='3',
# num_word=['four', '4']
# num_word=['five', '5']
# num_word=['six', '6']
# num_word=['seven', '7']
# num_word=['eight', '8']
# num_word=['nine', '9']
# numbers={0: 1, 11: 2, 1: 3} first_and_last=[1, 2] line_val=12
# Calibration: calibration_value=3297
# line='nfgrzrz494twogbrbcpvnine'
# num_word=['one', '1']
# num_word=['two', '2']
# num='2', at word_location=10, num='2',
# num_word=['three', '3']
# num_word=['four', '4']
# num='4', at word_location=7, num='4',
# num='4', at word_location=9, num='4',
# num_word=['five', '5']
# num_word=['six', '6']
# num_word=['seven', '7']
# num_word=['eight', '8']
# num_word=['nine', '9']
# num='9', at word_location=20, num='9',
# num='9', at word_location=8, num='9',
# numbers={10: 2, 7: 4, 9: 4, 20: 9, 8: 9} first_and_last=[4, 9] line_val=49
# Calibration: calibration_value=3346
# line='two5fdnksffour'
# num_word=['one', '1']
# num_word=['two', '2']
# num='2', at word_location=0, num='2',
# num_word=['three', '3']
# num_word=['four', '4']
# num='4', at word_location=10, num='4',
# num_word=['five', '5']
# num='5', at word_location=3, num='5',
# num_word=['six', '6']
# num_word=['seven', '7']
# num_word=['eight', '8']
# num_word=['nine', '9']
# numbers={0: 2, 10: 4, 3: 5} first_and_last=[2, 4] line_val=24
# Calibration: calibration_value=3370
# line='19threeninefive7xzmtzmkpjmnine'
# num_word=['one', '1']
# num='1', at word_location=0, num='1',
# num_word=['two', '2']
# num_word=['three', '3']
# num='3', at word_location=2, num='3',
# num_word=['four', '4']
# num_word=['five', '5']
# num='5', at word_location=11, num='5',
# num_word=['six', '6']
# num_word=['seven', '7']
# num='7', at word_location=15, num='7',
# num_word=['eight', '8']
# num_word=['nine', '9']
# num='9', at word_location=7, num='9',
# num='9', at word_location=26, num='9',
# num='9', at word_location=1, num='9',
# numbers={0: 1, 2: 3, 11: 5, 15: 7, 7: 9, 26: 9, 1: 9} first_and_last=[1, 9] line_val=19
# Calibration: calibration_value=3389
# line='six37sixninejqt'
# num_word=['one', '1']
# num_word=['two', '2']
# num_word=['three', '3']
# num='3', at word_location=3, num='3',
# num_word=['four', '4']
# num_word=['five', '5']
# num_word=['six', '6']
# num='6', at word_location=0, num='6',
# num='6', at word_location=5, num='6',
# num_word=['seven', '7']
# num='7', at word_location=4, num='7',
# num_word=['eight', '8']
# num_word=['nine', '9']
# num='9', at word_location=8, num='9',
# numbers={3: 3, 0: 6, 5: 6, 4: 7, 8: 9} first_and_last=[6, 9] line_val=69
# Calibration: calibration_value=3458
# line='kk28rqmlshb4'
# num_word=['one', '1']
# num_word=['two', '2']
# num='2', at word_location=2, num='2',
# num_word=['three', '3']
# num_word=['four', '4']
# num='4', at word_location=11, num='4',
# num_word=['five', '5']
# num_word=['six', '6']
# num_word=['seven', '7']
# num_word=['eight', '8']
# num='8', at word_location=3, num='8',
# num_word=['nine', '9']
# numbers={2: 2, 11: 4, 3: 8} first_and_last=[2, 4] line_val=24
# Calibration: calibration_value=3482
# line='qmhlxonefbgcrclbf4sqtcpmtlzdzhg4b'
# num_word=['one', '1']
# num='1', at word_location=5, num='1',
# num_word=['two', '2']
# num_word=['three', '3']
# num_word=['four', '4']
# num='4', at word_location=17, num='4',
# num='4', at word_location=31, num='4',
# num_word=['five', '5']
# num_word=['six', '6']
# num_word=['seven', '7']
# num_word=['eight', '8']
# num_word=['nine', '9']
# numbers={5: 1, 17: 4, 31: 4} first_and_last=[1, 4] line_val=14
# Calibration: calibration_value=3496
# line='leightwoplxmgrcjcxrfqncvjfdvpgckmqfqsfqjthreefour2djnsvctlt'
# num_word=['one', '1']
# num_word=['two', '2']
# num='2', at word_location=5, num='2',
# num='2', at word_location=49, num='2',
# num_word=['three', '3']
# num='3', at word_location=40, num='3',
# num_word=['four', '4']
# num='4', at word_location=45, num='4',
# num_word=['five', '5']
# num_word=['six', '6']
# num_word=['seven', '7']
# num_word=['eight', '8']
# num='8', at word_location=1, num='8',
# num_word=['nine', '9']
# numbers={5: 2, 49: 2, 40: 3, 45: 4, 1: 8} first_and_last=[8, 2] line_val=82
# Calibration: calibration_value=3578
# line='nseven7dphcjx36twosevenfour'
# num_word=['one', '1']
# num_word=['two', '2']
# num='2', at word_location=15, num='2',
# num_word=['three', '3']
# num='3', at word_location=13, num='3',
# num_word=['four', '4']
# num='4', at word_location=23, num='4',
# num_word=['five', '5']
# num_word=['six', '6']
# num='6', at word_location=14, num='6',
# num_word=['seven', '7']
# num='7', at word_location=1, num='7',
# num='7', at word_location=18, num='7',
# num='7', at word_location=6, num='7',
# num_word=['eight', '8']
# num_word=['nine', '9']
# numbers={15: 2, 13: 3, 23: 4, 14: 6, 1: 7, 18: 7, 6: 7} first_and_last=[7, 4] line_val=74
# Calibration: calibration_value=3652
# line='rdjkdfivetwo5sixfourfjkzbpjx'
# num_word=['one', '1']
# num_word=['two', '2']
# num='2', at word_location=9, num='2',
# num_word=['three', '3']
# num_word=['four', '4']
# num='4', at word_location=16, num='4',
# num_word=['five', '5']
# num='5', at word_location=5, num='5',
# num='5', at word_location=12, num='5',
# num_word=['six', '6']
# num='6', at word_location=13, num='6',
# num_word=['seven', '7']
# num_word=['eight', '8']
# num_word=['nine', '9']
# numbers={9: 2, 16: 4, 5: 5, 12: 5, 13: 6} first_and_last=[5, 4] line_val=54
# Calibration: calibration_value=3706
# line='fiveeightcdttxrxjxchf6oneddnpdgxlrpqxrgqtcbgdqhzzsxdt'
# num_word=['one', '1']
# num='1', at word_location=22, num='1',
# num_word=['two', '2']
# num_word=['three', '3']
# num_word=['four', '4']
# num_word=['five', '5']
# num='5', at word_location=0, num='5',
# num_word=['six', '6']
# num='6', at word_location=21, num='6',
# num_word=['seven', '7']
# num_word=['eight', '8']
# num='8', at word_location=4, num='8',
# num_word=['nine', '9']
# numbers={22: 1, 0: 5, 21: 6, 4: 8} first_and_last=[5, 1] line_val=51
# Calibration: calibration_value=3757
# line='5blgzg'
# num_word=['one', '1']
# num_word=['two', '2']
# num_word=['three', '3']
# num_word=['four', '4']
# num_word=['five', '5']
# num='5', at word_location=0, num='5',
# num_word=['six', '6']
# num_word=['seven', '7']
# num_word=['eight', '8']
# num_word=['nine', '9']
# numbers={0: 5} first_and_last=[5, 5] line_val=55
# Calibration: calibration_value=3812
# line='ninetdfive7'
# num_word=['one', '1']
# num_word=['two', '2']
# num_word=['three', '3']
# num_word=['four', '4']
# num_word=['five', '5']
# num='5', at word_location=6, num='5',
# num_word=['six', '6']
# num_word=['seven', '7']
# num='7', at word_location=10, num='7',
# num_word=['eight', '8']
# num_word=['nine', '9']
# num='9', at word_location=0, num='9',
# numbers={6: 5, 10: 7, 0: 9} first_and_last=[9, 7] line_val=97
# Calibration: calibration_value=3909
# line='eight9qldkxsevenfour'
# num_word=['one', '1']
# num_word=['two', '2']
# num_word=['three', '3']
# num_word=['four', '4']
# num='4', at word_location=16, num='4',
# num_word=['five', '5']
# num_word=['six', '6']
# num_word=['seven', '7']
# num='7', at word_location=11, num='7',
# num_word=['eight', '8']
# num='8', at word_location=0, num='8',
# num_word=['nine', '9']
# num='9', at word_location=5, num='9',
# numbers={16: 4, 11: 7, 0: 8, 5: 9} first_and_last=[8, 4] line_val=84
# Calibration: calibration_value=3993
# line='onegprdninefourgndvp7'
# num_word=['one', '1']
# num='1', at word_location=0, num='1',
# num_word=['two', '2']
# num_word=['three', '3']
# num_word=['four', '4']
# num='4', at word_location=11, num='4',
# num_word=['five', '5']
# num_word=['six', '6']
# num_word=['seven', '7']
# num='7', at word_location=20, num='7',
# num_word=['eight', '8']
# num_word=['nine', '9']
# num='9', at word_location=7, num='9',
# numbers={0: 1, 11: 4, 20: 7, 7: 9} first_and_last=[1, 7] line_val=17
# Calibration: calibration_value=4010
# line='four13znsmhvtmfour'
# num_word=['one', '1']
# num='1', at word_location=4, num='1',
# num_word=['two', '2']
# num_word=['three', '3']
# num='3', at word_location=5, num='3',
# num_word=['four', '4']
# num='4', at word_location=0, num='4',
# num='4', at word_location=14, num='4',
# num_word=['five', '5']
# num_word=['six', '6']
# num_word=['seven', '7']
# num_word=['eight', '8']
# num_word=['nine', '9']
# numbers={4: 1, 5: 3, 0: 4, 14: 4} first_and_last=[4, 4] line_val=44
# Calibration: calibration_value=4054
# line='threeqnvl9zzzfoneeight'
# num_word=['one', '1']
# num='1', at word_location=14, num='1',
# num_word=['two', '2']
# num_word=['three', '3']
# num='3', at word_location=0, num='3',
# num_word=['four', '4']
# num_word=['five', '5']
# num_word=['six', '6']
# num_word=['seven', '7']
# num_word=['eight', '8']
# num='8', at word_location=17, num='8',
# num_word=['nine', '9']
# num='9', at word_location=9, num='9',
# numbers={14: 1, 0: 3, 17: 8, 9: 9} first_and_last=[3, 8] line_val=38
# Calibration: calibration_value=4092
# line='sevenzkbxghrgftsxfndhlrcxlcj64'
# num_word=['one', '1']
# num_word=['two', '2']
# num_word=['three', '3']
# num_word=['four', '4']
# num='4', at word_location=29, num='4',
# num_word=['five', '5']
# num_word=['six', '6']
# num='6', at word_location=28, num='6',
# num_word=['seven', '7']
# num='7', at word_location=0, num='7',
# num_word=['eight', '8']
# num_word=['nine', '9']
# numbers={29: 4, 28: 6, 0: 7} first_and_last=[7, 4] line_val=74
# Calibration: calibration_value=4166
# line='kjlmclkqkjl76eightxdlonef4'
# num_word=['one', '1']
# num='1', at word_location=21, num='1',
# num_word=['two', '2']
# num_word=['three', '3']
# num_word=['four', '4']
# num='4', at word_location=25, num='4',
# num_word=['five', '5']
# num_word=['six', '6']
# num='6', at word_location=12, num='6',
# num_word=['seven', '7']
# num='7', at word_location=11, num='7',
# num_word=['eight', '8']
# num='8', at word_location=13, num='8',
# num_word=['nine', '9']
# numbers={21: 1, 25: 4, 12: 6, 11: 7, 13: 8} first_and_last=[7, 4] line_val=74
# Calibration: calibration_value=4240
# line='7oneninefive4fkonerjpzpq'
# num_word=['one', '1']
# num='1', at word_location=1, num='1',
# num='1', at word_location=15, num='1',
# num_word=['two', '2']
# num_word=['three', '3']
# num_word=['four', '4']
# num='4', at word_location=12, num='4',
# num_word=['five', '5']
# num='5', at word_location=8, num='5',
# num_word=['six', '6']
# num_word=['seven', '7']
# num='7', at word_location=0, num='7',
# num_word=['eight', '8']
# num_word=['nine', '9']
# num='9', at word_location=4, num='9',
# numbers={1: 1, 15: 1, 12: 4, 8: 5, 0: 7, 4: 9} first_and_last=[7, 1] line_val=71
# Calibration: calibration_value=4311
# line='248seventwo6six8vbfb'
# num_word=['one', '1']
# num_word=['two', '2']
# num='2', at word_location=8, num='2',
# num='2', at word_location=0, num='2',
# num_word=['three', '3']
# num_word=['four', '4']
# num='4', at word_location=1, num='4',
# num_word=['five', '5']
# num_word=['six', '6']
# num='6', at word_location=12, num='6',
# num='6', at word_location=11, num='6',
# num_word=['seven', '7']
# num='7', at word_location=3, num='7',
# num_word=['eight', '8']
# num='8', at word_location=2, num='8',
# num='8', at word_location=15, num='8',
# num_word=['nine', '9']
# numbers={8: 2, 0: 2, 1: 4, 12: 6, 11: 6, 3: 7, 2: 8, 15: 8} first_and_last=[2, 8] line_val=28
# Calibration: calibration_value=4339
# line='8khtwojr'
# num_word=['one', '1']
# num_word=['two', '2']
# num='2', at word_location=3, num='2',
# num_word=['three', '3']
# num_word=['four', '4']
# num_word=['five', '5']
# num_word=['six', '6']
# num_word=['seven', '7']
# num_word=['eight', '8']
# num='8', at word_location=0, num='8',
# num_word=['nine', '9']
# numbers={3: 2, 0: 8} first_and_last=[8, 2] line_val=82
# Calibration: calibration_value=4421
# line='hssqpxptsb2'
# num_word=['one', '1']
# num_word=['two', '2']
# num='2', at word_location=10, num='2',
# num_word=['three', '3']
# num_word=['four', '4']
# num_word=['five', '5']
# num_word=['six', '6']
# num_word=['seven', '7']
# num_word=['eight', '8']
# num_word=['nine', '9']
# numbers={10: 2} first_and_last=[2, 2] line_val=22
# Calibration: calibration_value=4443
# line='3qcf'
# num_word=['one', '1']
# num_word=['two', '2']
# num_word=['three', '3']
# num='3', at word_location=0, num='3',
# num_word=['four', '4']
# num_word=['five', '5']
# num_word=['six', '6']
# num_word=['seven', '7']
# num_word=['eight', '8']
# num_word=['nine', '9']
# numbers={0: 3} first_and_last=[3, 3] line_val=33
# Calibration: calibration_value=4476
# line='93xrm'
# num_word=['one', '1']
# num_word=['two', '2']
# num_word=['three', '3']
# num='3', at word_location=1, num='3',
# num_word=['four', '4']
# num_word=['five', '5']
# num_word=['six', '6']
# num_word=['seven', '7']
# num_word=['eight', '8']
# num_word=['nine', '9']
# num='9', at word_location=0, num='9',
# ...
# num_word=['four', '4']
# num_word=['five', '5']
# num='5', at word_location=14, num='5',
# num='5', at word_location=18, num='5',
# num_word=['six', '6']
# num_word=['seven', '7']
# num='7', at word_location=19, num='7',
# num='7', at word_location=20, num='7',
# num_word=['eight', '8']
# num_word=['nine', '9']
# num='9', at word_location=5, num='9',
# numbers={0: 3, 14: 5, 18: 5, 19: 7, 20: 7, 5: 9} first_and_last=[3, 7] line_val=37
# Calibration: calibration_value=53752
# line='mnkltgsgs4fivefivekxzzhjdtnzzvmvxdh'
# num_word=['one', '1']
# num_word=['two', '2']
# num_word=['three', '3']
# num_word=['four', '4']
# num='4', at word_location=9, num='4',
# num_word=['five', '5']
# num='5', at word_location=10, num='5',
# num='5', at word_location=14, num='5',
# num_word=['six', '6']
# num_word=['seven', '7']
# num_word=['eight', '8']
# num_word=['nine', '9']
# numbers={9: 4, 10: 5, 14: 5} first_and_last=[4, 5] line_val=45
# Calibration: calibration_value=53797
# line='blqtmklmkxcjtmxsrflffpzjcrninecd7rgdn8'
# num_word=['one', '1']
# num_word=['two', '2']
# num_word=['three', '3']
# num_word=['four', '4']
# num_word=['five', '5']
# num_word=['six', '6']
# num_word=['seven', '7']
# num='7', at word_location=32, num='7',
# num_word=['eight', '8']
# num='8', at word_location=37, num='8',
# num_word=['nine', '9']
# num='9', at word_location=26, num='9',
# numbers={32: 7, 37: 8, 26: 9} first_and_last=[9, 8] line_val=98
# Calibration: calibration_value=53895
# line='jgpktmfourdxzll8threerlssqvslnb'
# num_word=['one', '1']
# num_word=['two', '2']
# num_word=['three', '3']
# num='3', at word_location=16, num='3',
# num_word=['four', '4']
# num='4', at word_location=6, num='4',
# num_word=['five', '5']
# num_word=['six', '6']
# num_word=['seven', '7']
# num_word=['eight', '8']
# num='8', at word_location=15, num='8',
# num_word=['nine', '9']
# numbers={16: 3, 6: 4, 15: 8} first_and_last=[4, 3] line_val=43
# Calibration: calibration_value=53938
# line='4grvtbmlpqxgmzzksfgzvjggsqhffq1qcd'
# num_word=['one', '1']
# num='1', at word_location=30, num='1',
# num_word=['two', '2']
# num_word=['three', '3']
# num_word=['four', '4']
# num='4', at word_location=0, num='4',
# num_word=['five', '5']
# num_word=['six', '6']
# num_word=['seven', '7']
# num_word=['eight', '8']
# num_word=['nine', '9']
# numbers={30: 1, 0: 4} first_and_last=[4, 1] line_val=41
# Calibration: calibration_value=53979
# line='cninebtfvxfnmbtznfnzdh4zdmgtvbbnine'
# num_word=['one', '1']
# num_word=['two', '2']
# num_word=['three', '3']
# num_word=['four', '4']
# num='4', at word_location=22, num='4',
# num_word=['five', '5']
# num_word=['six', '6']
# num_word=['seven', '7']
# num_word=['eight', '8']
# num_word=['nine', '9']
# num='9', at word_location=1, num='9',
# num='9', at word_location=31, num='9',
# numbers={22: 4, 1: 9, 31: 9} first_and_last=[9, 9] line_val=99
# Calibration: calibration_value=54078
# line='1seven4vkvqcktfourvjtd4zqh'
# num_word=['one', '1']
# num='1', at word_location=0, num='1',
# num_word=['two', '2']
# num_word=['three', '3']
# num_word=['four', '4']
# num='4', at word_location=14, num='4',
# num='4', at word_location=6, num='4',
# num='4', at word_location=22, num='4',
# num_word=['five', '5']
# num_word=['six', '6']
# num_word=['seven', '7']
# num='7', at word_location=1, num='7',
# num_word=['eight', '8']
# num_word=['nine', '9']
# numbers={0: 1, 14: 4, 6: 4, 22: 4, 1: 7} first_and_last=[1, 4] line_val=14
# Calibration: calibration_value=54092
# line='8eight7lhmx89four'
# num_word=['one', '1']
# num_word=['two', '2']
# num_word=['three', '3']
# num_word=['four', '4']
# num='4', at word_location=13, num='4',
# num_word=['five', '5']
# num_word=['six', '6']
# num_word=['seven', '7']
# num='7', at word_location=6, num='7',
# num_word=['eight', '8']
# num='8', at word_location=1, num='8',
# num='8', at word_location=0, num='8',
# num='8', at word_location=11, num='8',
# num_word=['nine', '9']
# num='9', at word_location=12, num='9',
# numbers={13: 4, 6: 7, 1: 8, 0: 8, 11: 8, 12: 9} first_and_last=[8, 4] line_val=84
# Calibration: calibration_value=54176
# line='xrpxkdrf8fhl29fivexzsrdbmksixpvlk'
# num_word=['one', '1']
# num_word=['two', '2']
# num='2', at word_location=12, num='2',
# num_word=['three', '3']
# num_word=['four', '4']
# num_word=['five', '5']
# num='5', at word_location=14, num='5',
# num_word=['six', '6']
# num='6', at word_location=26, num='6',
# num_word=['seven', '7']
# num_word=['eight', '8']
# num='8', at word_location=8, num='8',
# num_word=['nine', '9']
# num='9', at word_location=13, num='9',
# numbers={12: 2, 14: 5, 26: 6, 8: 8, 13: 9} first_and_last=[8, 6] line_val=86
# Calibration: calibration_value=54262
# line='8tvfplhxxxzr'
# num_word=['one', '1']
# num_word=['two', '2']
# num_word=['three', '3']
# num_word=['four', '4']
# num_word=['five', '5']
# num_word=['six', '6']
# num_word=['seven', '7']
# num_word=['eight', '8']
# num='8', at word_location=0, num='8',
# num_word=['nine', '9']
# numbers={0: 8} first_and_last=[8, 8] line_val=88
# Calibration: calibration_value=54350
# line='twothree8nine2ninegfbrchxmmfive'
# num_word=['one', '1']
# num_word=['two', '2']
# num='2', at word_location=0, num='2',
# num='2', at word_location=13, num='2',
# num_word=['three', '3']
# num='3', at word_location=3, num='3',
# num_word=['four', '4']
# num_word=['five', '5']
# num='5', at word_location=27, num='5',
# num_word=['six', '6']
# num_word=['seven', '7']
# num_word=['eight', '8']
# num='8', at word_location=8, num='8',
# num_word=['nine', '9']
# num='9', at word_location=9, num='9',
# num='9', at word_location=14, num='9',
# numbers={0: 2, 13: 2, 3: 3, 27: 5, 8: 8, 9: 9, 14: 9} first_and_last=[2, 5] line_val=25
# Calibration: calibration_value=54375
# line='9threeskhgsnsvvzpnnv2seven4'
# num_word=['one', '1']
# num_word=['two', '2']
# num='2', at word_location=20, num='2',
# num_word=['three', '3']
# num='3', at word_location=1, num='3',
# num_word=['four', '4']
# num='4', at word_location=26, num='4',
# num_word=['five', '5']
# num_word=['six', '6']
# num_word=['seven', '7']
# num='7', at word_location=21, num='7',
# num_word=['eight', '8']
# num_word=['nine', '9']
# num='9', at word_location=0, num='9',
# numbers={20: 2, 1: 3, 26: 4, 21: 7, 0: 9} first_and_last=[9, 4] line_val=94
# Calibration: calibration_value=54469
# line='8sbzvncqszzdflznpqfddeight3'
# num_word=['one', '1']
# num_word=['two', '2']
# num_word=['three', '3']
# num='3', at word_location=26, num='3',
# num_word=['four', '4']
# num_word=['five', '5']
# num_word=['six', '6']
# num_word=['seven', '7']
# num_word=['eight', '8']
# num='8', at word_location=21, num='8',
# num='8', at word_location=0, num='8',
# num_word=['nine', '9']
# numbers={26: 3, 21: 8, 0: 8} first_and_last=[8, 3] line_val=83
# Calibration: calibration_value=54552
# line='1eightzfivehlmhnqbnnr'
# num_word=['one', '1']
# num='1', at word_location=0, num='1',
# num_word=['two', '2']
# num_word=['three', '3']
# num_word=['four', '4']
# num_word=['five', '5']
# num='5', at word_location=7, num='5',
# num_word=['six', '6']
# num_word=['seven', '7']
# num_word=['eight', '8']
# num='8', at word_location=1, num='8',
# num_word=['nine', '9']
# numbers={0: 1, 7: 5, 1: 8} first_and_last=[1, 5] line_val=15
# Calibration: calibration_value=54567
# line='sixfivefjfqftjvcdzkpbkhnvqrqqhpvmgnq75pfk'
# num_word=['one', '1']
# num_word=['two', '2']
# num_word=['three', '3']
# num_word=['four', '4']
# num_word=['five', '5']
# num='5', at word_location=3, num='5',
# num='5', at word_location=37, num='5',
# num_word=['six', '6']
# num='6', at word_location=0, num='6',
# num_word=['seven', '7']
# num='7', at word_location=36, num='7',
# num_word=['eight', '8']
# num_word=['nine', '9']
# numbers={3: 5, 37: 5, 0: 6, 36: 7} first_and_last=[6, 5] line_val=65
# Calibration: calibration_value=54632
# line='mtfvjbbpdeight1'
# num_word=['one', '1']
# num='1', at word_location=14, num='1',
# num_word=['two', '2']
# num_word=['three', '3']
# num_word=['four', '4']
# num_word=['five', '5']
# num_word=['six', '6']
# num_word=['seven', '7']
# num_word=['eight', '8']
# num='8', at word_location=9, num='8',
# num_word=['nine', '9']
# numbers={14: 1, 9: 8} first_and_last=[8, 1] line_val=81
# Calibration: calibration_value=54713
# line='txtfqxvbrnine2'
# num_word=['one', '1']
# num_word=['two', '2']
# num='2', at word_location=13, num='2',
# num_word=['three', '3']
# num_word=['four', '4']
# num_word=['five', '5']
# num_word=['six', '6']
# num_word=['seven', '7']
# num_word=['eight', '8']
# num_word=['nine', '9']
# num='9', at word_location=9, num='9',
# numbers={13: 2, 9: 9} first_and_last=[9, 2] line_val=92
# Calibration: calibration_value=54805
# line='sevenptvlbpkdzpp8tnlvkdjjpbt'
# num_word=['one', '1']
# num_word=['two', '2']
# num_word=['three', '3']
# num_word=['four', '4']
# num_word=['five', '5']
# num_word=['six', '6']
# num_word=['seven', '7']
# num='7', at word_location=0, num='7',
# num_word=['eight', '8']
# num='8', at word_location=16, num='8',
# num_word=['nine', '9']
# numbers={0: 7, 16: 8} first_and_last=[7, 8] line_val=78
# Calibration: calibration_value=54883
# line='qgoneighteighttgrdmljtzbblrtskvfivevbbp1'
# num_word=['one', '1']
# num='1', at word_location=2, num='1',
# num='1', at word_location=39, num='1',
# num_word=['two', '2']
# num_word=['three', '3']
# num_word=['four', '4']
# num_word=['five', '5']
# num='5', at word_location=31, num='5',
# num_word=['six', '6']
# num_word=['seven', '7']
# num_word=['eight', '8']
# num='8', at word_location=4, num='8',
# num='8', at word_location=9, num='8',
# num_word=['nine', '9']
# numbers={2: 1, 39: 1, 31: 5, 4: 8, 9: 8} first_and_last=[1, 1] line_val=11
# Calibration: calibration_value=54894
# line='ninethreejbxseven392'
# num_word=['one', '1']
# num_word=['two', '2']
# num='2', at word_location=19, num='2',
# num_word=['three', '3']
# num='3', at word_location=4, num='3',
# num='3', at word_location=17, num='3',
# num_word=['four', '4']
# num_word=['five', '5']
# num_word=['six', '6']
# num_word=['seven', '7']
# num='7', at word_location=12, num='7',
# num_word=['eight', '8']
# num_word=['nine', '9']
# num='9', at word_location=0, num='9',
# num='9', at word_location=18, num='9',
# numbers={19: 2, 4: 3, 17: 3, 12: 7, 0: 9, 18: 9} first_and_last=[9, 2] line_val=92
# Calibration: calibration_value=54986
# line='86pbrnhhhpn'
# num_word=['one', '1']
# num_word=['two', '2']
# num_word=['three', '3']
# num_word=['four', '4']
# num_word=['five', '5']
# num_word=['six', '6']
# num='6', at word_location=1, num='6',
# num_word=['seven', '7']
# num_word=['eight', '8']
# num='8', at word_location=0, num='8',
# num_word=['nine', '9']
# numbers={1: 6, 0: 8} first_and_last=[8, 6] line_val=86
# Calibration: calibration_value=55072
# line='sevenonenine5bcqrttts6fourthree'
# num_word=['one', '1']
# num='1', at word_location=5, num='1',
# num_word=['two', '2']
# num_word=['three', '3']
# num='3', at word_location=26, num='3',
# num_word=['four', '4']
# num='4', at word_location=22, num='4',
# num_word=['five', '5']
# num='5', at word_location=12, num='5',
# num_word=['six', '6']
# num='6', at word_location=21, num='6',
# num_word=['seven', '7']
# num='7', at word_location=0, num='7',
# num_word=['eight', '8']
# num_word=['nine', '9']
# num='9', at word_location=8, num='9',
# numbers={5: 1, 26: 3, 22: 4, 12: 5, 21: 6, 0: 7, 8: 9} first_and_last=[7, 3] line_val=73
# Calibration: calibration_value=55145
# line='4seventwo5ngnbkqftzdfive4lhsthree'
# num_word=['one', '1']
# num_word=['two', '2']
# num='2', at word_location=6, num='2',
# num_word=['three', '3']
# num='3', at word_location=28, num='3',
# num_word=['four', '4']
# num='4', at word_location=0, num='4',
# num='4', at word_location=24, num='4',
# num_word=['five', '5']
# num='5', at word_location=20, num='5',
# num='5', at word_location=9, num='5',
# num_word=['six', '6']
# num_word=['seven', '7']
# num='7', at word_location=1, num='7',
# num_word=['eight', '8']
# num_word=['nine', '9']
# numbers={6: 2, 28: 3, 0: 4, 24: 4, 20: 5, 9: 5, 1: 7} first_and_last=[4, 3] line_val=43
# Calibration: calibration_value=55188
# line='36seven97klhbqbpgninerb'
# num_word=['one', '1']
# num_word=['two', '2']
# num_word=['three', '3']
# num='3', at word_location=0, num='3',
# num_word=['four', '4']
# num_word=['five', '5']
# num_word=['six', '6']
# num='6', at word_location=1, num='6',
# num_word=['seven', '7']
# num='7', at word_location=2, num='7',
# num='7', at word_location=8, num='7',
# num_word=['eight', '8']
# num_word=['nine', '9']
# num='9', at word_location=17, num='9',
# num='9', at word_location=7, num='9',
# numbers={0: 3, 1: 6, 2: 7, 8: 7, 17: 9, 7: 9} first_and_last=[3, 9] line_val=39
# Calibration: calibration_value=55227
# line='813eight'
# num_word=['one', '1']
# num='1', at word_location=1, num='1',
# num_word=['two', '2']
# num_word=['three', '3']
# num='3', at word_location=2, num='3',
# num_word=['four', '4']
# num_word=['five', '5']
# num_word=['six', '6']
# num_word=['seven', '7']
# num_word=['eight', '8']
# num='8', at word_location=3, num='8',
# num='8', at word_location=0, num='8',
# num_word=['nine', '9']
# numbers={1: 1, 2: 3, 3: 8, 0: 8} first_and_last=[8, 8] line_val=88
# Calibration: calibration_value=55315
# line='ncbfctqlsnfive1brqpthree4'
# num_word=['one', '1']
# num='1', at word_location=14, num='1',
# num_word=['two', '2']
# num_word=['three', '3']
# num='3', at word_location=19, num='3',
# num_word=['four', '4']
# num='4', at word_location=24, num='4',
# num_word=['five', '5']
# num='5', at word_location=10, num='5',
# num_word=['six', '6']
# num_word=['seven', '7']
# num_word=['eight', '8']
# num_word=['nine', '9']
# numbers={14: 1, 19: 3, 24: 4, 10: 5} first_and_last=[5, 4] line_val=54
# Calibration: calibration_value=55369
# line='ksbsddjcknsevensix293three'
# num_word=['one', '1']
# num_word=['two', '2']
# num='2', at word_location=18, num='2',
# num_word=['three', '3']
# num='3', at word_location=21, num='3',
# num='3', at word_location=20, num='3',
# num_word=['four', '4']
# num_word=['five', '5']
# num_word=['six', '6']
# num='6', at word_location=15, num='6',
# num_word=['seven', '7']
# num='7', at word_location=10, num='7',
# num_word=['eight', '8']
# num_word=['nine', '9']
# num='9', at word_location=19, num='9',
# numbers={18: 2, 21: 3, 20: 3, 15: 6, 10: 7, 19: 9} first_and_last=[7, 3] line_val=73
# Calibration: calibration_value=55442
# line='rljzzbvd3zkmbpjt9eightninesnlrsone'
# num_word=['one', '1']
# num='1', at word_location=31, num='1',
# num_word=['two', '2']
# num_word=['three', '3']
# num='3', at word_location=8, num='3',
# num_word=['four', '4']
# num_word=['five', '5']
# num_word=['six', '6']
# num_word=['seven', '7']
# num_word=['eight', '8']
# num='8', at word_location=17, num='8',
# num_word=['nine', '9']
# num='9', at word_location=22, num='9',
# num='9', at word_location=16, num='9',
# numbers={31: 1, 8: 3, 17: 8, 22: 9, 16: 9} first_and_last=[3, 1] line_val=31
# Calibration: calibration_value=55473
# line='97ninesevenrhchvppnztvfbfpkzrbcone'
# num_word=['one', '1']
# num='1', at word_location=31, num='1',
# num_word=['two', '2']
# num_word=['three', '3']
# num_word=['four', '4']
# num_word=['five', '5']
# num_word=['six', '6']
# num_word=['seven', '7']
# num='7', at word_location=6, num='7',
# num='7', at word_location=1, num='7',
# num_word=['eight', '8']
# num_word=['nine', '9']
# num='9', at word_location=2, num='9',
# num='9', at word_location=0, num='9',
# numbers={31: 1, 6: 7, 1: 7, 2: 9, 0: 9} first_and_last=[9, 1] line_val=91
# Calibration: calibration_value=55564
# line='sevendxbninefour2fourclmln'
# num_word=['one', '1']
# num_word=['two', '2']
# num='2', at word_location=16, num='2',
# num_word=['three', '3']
# num_word=['four', '4']
# num='4', at word_location=12, num='4',
# num='4', at word_location=17, num='4',
# num_word=['five', '5']
# num_word=['six', '6']
# num_word=['seven', '7']
# num='7', at word_location=0, num='7',
# num_word=['eight', '8']
# num_word=['nine', '9']
# num='9', at word_location=8, num='9',
# numbers={16: 2, 12: 4, 17: 4, 0: 7, 8: 9} first_and_last=[7, 4] line_val=74
# Calibration: calibration_value=55638
# line='1rdtwofjvdllht5eightsixfourbl'
# num_word=['one', '1']
# num='1', at word_location=0, num='1',
# num_word=['two', '2']
# num='2', at word_location=3, num='2',
# num_word=['three', '3']
# num_word=['four', '4']
# num='4', at word_location=23, num='4',
# num_word=['five', '5']
# num='5', at word_location=14, num='5',
# num_word=['six', '6']
# num='6', at word_location=20, num='6',
# num_word=['seven', '7']
# num_word=['eight', '8']
# num='8', at word_location=15, num='8',
# num_word=['nine', '9']
# numbers={0: 1, 3: 2, 23: 4, 14: 5, 20: 6, 15: 8} first_and_last=[1, 4] line_val=14
# Calibration: calibration_value=55652
# Calbration: 55652

# %% [markdown]
# # Day 2

# %% [markdown]
# https://adventofcode.com/2023/day/2

# %%
sample_text = """Game 1: 3 blue, 4 red; 1 red, 2 green, 6 blue; 2 green
Game 2: 1 blue, 2 green; 3 green, 4 blue, 1 red; 1 green, 1 blue
Game 3: 8 green, 6 blue, 20 red; 5 blue, 4 red, 13 green; 5 green, 1 red
Game 4: 1 green, 3 red, 6 blue; 3 green, 6 red; 3 green, 15 blue, 14 red
Game 5: 6 red, 1 blue, 3 green; 2 blue, 1 red, 2 green"""
print(sample_text)

#Test: only 12 red cubes, 13 green cubes, and 14 blue cubes
# Result = Games 1,2,5 = ID Total: 8
# Out:
# Game 1: 3 blue, 4 red; 1 red, 2 green, 6 blue; 2 green
# Game 2: 1 blue, 2 green; 3 green, 4 blue, 1 red; 1 green, 1 blue
# Game 3: 8 green, 6 blue, 20 red; 5 blue, 4 red, 13 green; 5 green, 1 red
# Game 4: 1 green, 3 red, 6 blue; 3 green, 6 red; 3 green, 15 blue, 14 red
# Game 5: 6 red, 1 blue, 3 green; 2 blue, 1 red, 2 green

# %%
def handful_to_set(handful):
  cubeset = handful.split(",")
  #print(f"{cubeset=}")
  return cubeset

def get_game_maxes(game_body):
  max = {"red":0, "green":0, "blue":0}
  handfuls = game_body.split(";")
  for handful in handfuls:
    cubeset = handful_to_set(handful)
    for cube in cubeset:
      cube_count = int(cube.split()[0])
      colour = cube.split()[1]
      if max[colour] < cube_count:
        max[colour] = cube_count
  print(f"{max=}")
  return max



def read_games(text):
  games = {}
  for line in text.splitlines():
    print(f"{line=}")
    game_id = int(line.split(":")[0].split(" ")[1])
    game_body = line.split(":")[1]
    print(f"{game_id=} {game_body=} ")
    games[game_id]= get_game_maxes(game_body)
  return games

def constraint_to_rule(constrain_text):
  rule = {}
  cubeset = handful_to_set(constraint_text)
  for cube in cubeset:
    cube_count = int(cube.split()[0])
    colour = cube.split()[1]
    rule[colour] = cube_count
  return rule


def check_games_against_rule(games_max, rule):
  for game in games_max:
    if gam

games_max = read_games(sample_text)
print(f"{games_max=}")


constraint_text = "12 red, 13 green, 14 blue"
rule = constraint_to_rule(constraint_text)

print(f"{rule=}")
# Out:
# line='Game 1: 3 blue, 4 red; 1 red, 2 green, 6 blue; 2 green'
# game_id=1 game_body=' 3 blue, 4 red; 1 red, 2 green, 6 blue; 2 green'
# max={'red': 4, 'green': 2, 'blue': 6}
# line='Game 2: 1 blue, 2 green; 3 green, 4 blue, 1 red; 1 green, 1 blue'
# game_id=2 game_body=' 1 blue, 2 green; 3 green, 4 blue, 1 red; 1 green, 1 blue'
# max={'red': 1, 'green': 3, 'blue': 4}
# line='Game 3: 8 green, 6 blue, 20 red; 5 blue, 4 red, 13 green; 5 green, 1 red'
# game_id=3 game_body=' 8 green, 6 blue, 20 red; 5 blue, 4 red, 13 green; 5 green, 1 red'
# max={'red': 20, 'green': 13, 'blue': 6}
# line='Game 4: 1 green, 3 red, 6 blue; 3 green, 6 red; 3 green, 15 blue, 14 red'
# game_id=4 game_body=' 1 green, 3 red, 6 blue; 3 green, 6 red; 3 green, 15 blue, 14 red'
# max={'red': 14, 'green': 3, 'blue': 15}
# line='Game 5: 6 red, 1 blue, 3 green; 2 blue, 1 red, 2 green'
# game_id=5 game_body=' 6 red, 1 blue, 3 green; 2 blue, 1 red, 2 green'
# max={'red': 6, 'green': 3, 'blue': 2}
# games_max={1: {'red': 4, 'green': 2, 'blue': 6}, 2: {'red': 1, 'green': 3, 'blue': 4}, 3: {'red': 20, 'green': 13, 'blue': 6}, 4: {'red': 14, 'green': 3, 'blue': 15}, 5: {'red': 6, 'green': 3, 'blue': 2}}
# rule={'red': 12, 'green': 13, 'blue': 14}
